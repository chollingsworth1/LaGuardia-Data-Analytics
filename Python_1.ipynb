# %% [markdown]
# <a href="https://colab.research.google.com/github/chollingsworth1/LaGuardia-Data-Analytics/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#to ensure data was imported correctly
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
#to see how many tested in each school
df.groupby(['School Name'])['Total Tested'].count()
# Out:
# School Name
# 47 The American Sign Language and English Secondar    356
# A. Philip Randolph Campus High School                 459
# ACORN Community High School                           364
# Abraham Lincoln High School                           480
# Abraham Lincoln Yabc                                  248
#                                                      ...
# Young Women's Leadership School                       378
# Young Women's Leadership School of Brooklyn           337
# Young Women's Leadership School of the Bronx          142
# Young Women's Leadership School, Astoria              338
# Young Women's Leadership School, Queens               391
# Name: Total Tested, Length: 1012, dtype: int64

# %%
#select a school for comparison "Abraham Lincoln High School"
df[df['School Name'] == 'Abraham Lincoln High School']
# Out:
#        School DBN                  School Name School Level  \
# 12515      21K410  Abraham Lincoln High School  High school
# 12516      21K410  Abraham Lincoln High School  High school
# 12517      21K410  Abraham Lincoln High School  High school
# 12518      21K410  Abraham Lincoln High School  High school
# 12519      21K410  Abraham Lincoln High School  High school
# ...           ...                          ...          ...
# 186033     21K410  Abraham Lincoln High School  High school
# 186034     21K410  Abraham Lincoln High School  High school
# 186035     21K410  Abraham Lincoln High School  High school
# 186036     21K410  Abraham Lincoln High School  High school
# 186037     21K410  Abraham Lincoln High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 12515         Algebra2/Trigonometry  2015           130       72.7
# 12516         Algebra2/Trigonometry  2016           142       70.5
# ...

# %%
df.groupby('School Name').max('Mean Score')
# Out:
#                                                     Year  Total Tested
# School Name
# 47 The American Sign Language and English Secondar  2017           119
# A. Philip Randolph Campus High School               2017           522
# ACORN Community High School                         2017           164
# Abraham Lincoln High School                         2017          1041
# Abraham Lincoln Yabc                                2017            66
# ...                                                  ...           ...
# Young Women's Leadership School                     2017           118
# Young Women's Leadership School of Brooklyn         2017           115
# Young Women's Leadership School of the Bronx        2017           122
# Young Women's Leadership School, Astoria            2017           251
# Young Women's Leadership School, Queens             2017           177
#
# [1012 rows x 2 columns]

# %%
#to import matplotlib
import matplotlib.pyplot as plt

# %%
mean_scores = df.groupby('School Name').max('Mean Score')

# %%
#Histogram
plt.hist(mean_scores)
plt.title('mean scores by school')
plt.xlabel('Average Mean Score')
plt.ylabel('Number of Schools')
plt.show()
